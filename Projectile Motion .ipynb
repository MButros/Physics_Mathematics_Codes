# %% [markdown]
# This notebook illustrates the effect of the launchh angle on the range of an object under projectile motion

# %%
import numpy as np 
import matplotlib.pyplot as plt

# %% [markdown]
# Initialize variables:
#
# velocity, acceleration due to gravity

# %%
v = 30 
g = 9.81

# %% [markdown]
# Increment theta 25 to 60 then find  t, x, y
#
# Define x and y as arrays

# %%
theta = np.arange(25,65,5)[None,:]/180.0*np.pi #convert to radians, watch out for modulo division

plt.figure()

tmax = ((2 * v) * np.sin(theta)) / g
timemat = tmax*np.linspace(0,1,100)[:,None] #create time vectors for each angle

x = ((v * timemat) * np.cos(theta))
y = ((v * timemat) * np.sin(theta)) - ((0.5 * g) * (timemat ** 2))

plt.plot(x,y) #plot each dataset: columns of x and columns of y
plt.ylim([0,35])
plot.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 13
#      11 plt.plot(x,y) #plot each dataset: columns of x and columns of y
#      12 plt.ylim([0,35])
# ---> 13 plot.show()
#
# NameError: name 'plot' is not defined
